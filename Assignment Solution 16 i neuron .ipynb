# %%
##1. Create a list called years_list, starting with the year of your birth, and each year thereafter until ,
     # the year of your fifth birthday. For example, if you were born in 1980. the list would be years_list,
    # = [1980, 1981, 1982, 1983, 1984, 1985].

Ans-. Replace the year of birth with your actual birth year
    birth_year = 2000

     #Create a list of years from birth year to fifth birthday
    years_list = [year for year in range(birth_year, birth_year+6)]

     #Print the list
    print(years_list)


##2. In which year in years_list was your third birthday? Remember, you were 0 years of age for your first year.

Ans-.If I was born in 2000, then my third birthday would have been in the year 2003.

    In the years_list created earlier, 2000 is my birth year and 2003 is the third year of my life,
    which is the year when I turned three years old. Therefore, the element at index 3 of years_list,
    would represent the year when I turned three years old.

    Here's the code to print the year of my third birthday:
    # Replace the birth_year with your actual birth year
    birth_year = 2000

    # Create the years_list
    years_list = [year for year in range(birth_year, birth_year+6)]

    # Print the year of my third birthday
    print(years_list[3])


##3.In the years list, which year were you the oldest?

Ans-.If I was born in 2000 and the years_list includes all the years from my birth year until my fifth birthday,
    then the year when I was the oldest would be 2005, which is the last year in the years_list.

    Here's the code to print the year when I was the oldest:
    # Replace the birth_year with your actual birth year
    birth_year = 2000

    # Create the years_list
    years_list = [year for year in range(birth_year, birth_year+6)]

    # Print the year when I was the oldest
    print(years_list[-1])


##4. Make a list called things with these three strings as elements: "mozzarella", "cinderella", "salmonella".

Ans-.# Create the list of things
    things = ["mozzarella", "cinderella", "salmonella"]

    # Print the list
    print(things)


##5. Capitalize the element in things that refers to a person and then print the list. Did it change the element in the list?

Ans-.To capitalize the element in things that refers to a person (i.e., "cinderella"), you can use the capitalize() method,
    which capitalizes the first letter of a string.

    Here's the code to capitalize the "cinderella" element in things and print the list:
    # Create the list of things
    things = ["mozzarella", "cinderella", "salmonella"]

    # Capitalize the "cinderella" element
    things[1] = things[1].capitalize()

    # Print the list
    print(things)
    
    
    Output:
    ['mozzarella', 'Cinderella', 'salmonella']
    
    As you can see, the "cinderella" element has been capitalized to "Cinderella" in the list. 
    Yes, it did change the element in the list.



##6. Make a surprise list with the elements "Groucho," "Chico," and "Harpo."

Ans-.# Create the surprise list
    surprise = ["Groucho", "Chico", "Harpo"]

    # Print the list
    print(surprise)
    
    Output:

    ['Groucho', 'Chico', 'Harpo']



##7. Lowercase the last element of the surprise list, reverse it, and then capitalize it.

Ans-.# Create the surprise list
    surprise = ["Groucho", "Chico", "Harpo"]

    # Get the last element, lowercase it, reverse it, and capitalize it
    last_element = surprise[-1]
    last_element = last_element.lower()[::-1].capitalize()

    # Replace the last element in surprise with the modified element
    surprise[-1] = last_element

    # Print the modified surprise list
    print(surprise)
    
    Output:
        
    ['Groucho', 'Chico', 'Oprah']

    As you can see, the last element of surprise has been modified as per the given instructions.
    It was first converted to lowercase, then reversed, and finally capitalized. The modified element was then replaced,
    in the list, and the final list was printed.






##8. Make an English-to-French dictionary called e2f and print it. Here are your starter words: dog is chien, 
    #cat is chat, and walrus is morse.

Ans-.# Create the e2f dictionary
    e2f = {"dog": "chien", "cat": "chat", "walrus": "morse"}

    # Print the dictionary
    print(e2f)
    
    Output:
        
    {'dog': 'chien', 'cat': 'chat', 'walrus': 'morse'}

    As you can see, the e2f dictionary has been created with the given starter words, and it has been printed.


##9. Write the French word for walrus in your three-word dictionary e2f.

Ans-.The French word for "walrus" in the e2f dictionary is "morse". You can access it using the key "walrus" as follows:
    
    # Create the e2f dictionary
    e2f = {"dog": "chien", "cat": "chat", "walrus": "morse"}

    # Print the French word for "walrus"
    print(e2f["walrus"])
    
    Output:
        
    morse

    As you can see, the French word for "walrus" in the e2f dictionary is "morse".
    
    
    
##10. Make a French-to-English dictionary called f2e from e2f. Use the items method.

Ans-.Here is how you can create a French-to-English dictionary called f2e from the e2f dictionary using the items() method:
    
    # Create the e2f dictionary
    e2f = {"dog": "chien", "cat": "chat", "walrus": "morse"}

    # Create the f2e dictionary using the items() method of e2f
    f2e = {french: english for english, french in e2f.items()}

    # Print the f2e dictionary
    print(f2e)
    
    Output:

    {'chien': 'dog', 'chat': 'cat', 'morse': 'walrus'}
    
    As you can see, the f2e dictionary has been created from the e2f dictionary using the items() method. 
    The key-value pairs in e2f have been swapped to create f2e, and the final dictionary has been printed.



##11. Print the English version of the French word chien using f2e.

Ans-.Here is how you can print the English version of the French word "chien" using the f2e dictionary:
    # Create the e2f dictionary
    e2f = {"dog": "chien", "cat": "chat", "walrus": "morse"}

    # Create the f2e dictionary using the items() method of e2f
    f2e = {french: english for english, french in e2f.items()}

    # Print the English version of "chien" using f2e
    print(f2e["chien"])
    
    Output:
        
    dog

    As you can see, the English version of the French word "chien" is "dog", and it can be printed using the f2e dictionary.

##12. Make and print a set of English words from the keys in e2f.

Ans-.

##13. Make a multilevel dictionary called life. Use these strings for the topmost keys: 'animals', 'plants', and 'other'.
     #Make the 'animals' key refer to another dictionary with the keys 'cats', 'octopi', and 'emus'. Make the 'cats' key,
    #refer to a list of strings with the values 'Henri', 'Grumpy', and 'Lucy'. Make all the other keys refer to empty,
    #dictionaries.

Ans-.# Create the life dictionary
    life = {'animals': {'cats': ['Henri', 'Grumpy', 'Lucy'], 'octopi': {}, 'emus': {}},
        'plants': {},
        'other': {}}

    # Print the life dictionary
    print(life)
    
    Output:
        
    {'animals': {'cats': ['Henri', 'Grumpy', 'Lucy'], 'octopi': {}, 'emus': {}}, 'plants': {}, 'other': {}}

    As you can see, the life dictionary has been created with the specified keys and values, and it has been printed.
    The 'animals' key refers to another dictionary with the keys 'cats', 'octopi', and 'emus', and the 'cats' key refers,
    to a list of strings with the values 'Henri', 'Grumpy', and 'Lucy'. The 'plants' and 'other' keys refer to empty,
    dictionaries.


##14. Print the top-level keys of life.

Ans-.# Create the life dictionary
    life = {'animals': {'cats': ['Henri', 'Grumpy', 'Lucy'], 'octopi': {}, 'emus': {}},
        'plants': {},
        'other': {}}

    # Print the top-level keys of the life dictionary
    print(life.keys())
    
    Output:
        
    dict_keys(['animals', 'plants', 'other'])
    
    As you can see, the keys() method is used to print the top-level keys of the life dictionary, which are 'animals',
    'plants', and 'other'.



##15. Print the keys for life['animals'].

Ans-.# Create the life dictionary
    life = {'animals': {'cats': ['Henri', 'Grumpy', 'Lucy'], 'octopi': {}, 'emus': {}},
        'plants': {},
        'other': {}}

    # Print the keys for life['animals']
    print(life['animals'].keys())
    
    Output:
        
    dict_keys(['cats', 'octopi', 'emus'])

    As you can see, the keys() method is used to print the keys for life['animals'], which are 'cats', 'octopi', and 'emus'.

##16. Print the values for life['animals']['cats']

Ans-.# Create the life dictionary
    life = {'animals': {'cats': ['Henri', 'Grumpy', 'Lucy'], 'octopi': {}, 'emus': {}},
        'plants': {},
        'other': {}}

    # Print the values for life['animals']['cats']
    print(life['animals']['cats'])
    
    Output:
        
    ['Henri', 'Grumpy', 'Lucy']

    As you can see, the list of values for life['animals']['cats'] is printed, which are 'Henri', 'Grumpy', and 'Lucy'.
