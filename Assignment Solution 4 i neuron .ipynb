# %%
## 1. What exactly is []?

Ans-.[] is an empty list in Python.


## 2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)

Ans-.To assign the value 'hello' as the third value in the list stored in the variable spam, you can use the following code:
     spam[2] = 'hello'
    -This will change the list to [2, 4, 'hello', 8, 10].  



##Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.


## 3. What is the value of spam[int(int('3' * 2) / 11)]?

Ans-.The value of spam[int(int('3' * 2) / 11)] is 'd'.First, the string '3' is multiplied by 2 to get '33', 
     which is then converted to an integer and divided by 11 to get 3. The expression then becomes spam[3],
     which corresponds to the fourth element of the list ['a', 'b', 'c', 'd'].



## 4. What is the value of spam[-1]?

Ans-.The value of spam[-1] is 'd', which is the last element in the list.



## 5. What is the value of spam[:2]?

Ans-.The value of spam[:2] is ['a', 'b'], which is a new list containing the first two elements of the original list.


##Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.


## 6. What is the value of bacon.index('cat')?

Ans-.The value of bacon.index('cat') is 1.
    This method returns the index of the first occurrence of the specified value in the list.


## 7. How does bacon.append(99) change the look of the list value in bacon?

Ans-.After bacon.append(99), the list value in bacon would be [3.14, 'cat', 11, 'cat', True, 99].
    The append() method adds the specified element to the end of the list.


## 8. How does bacon.remove('cat') change the look of the list in bacon?

Ans-.After bacon.remove('cat'), the list value in bacon would be [3.14, 11, 'cat', True]. 
    The remove() method removes the first occurrence of the specified value from the list.

    
## 9. What are the list concatenation and list replication operators?

Ans-.The list concatenation operator is +, which combines two lists into a new list. The list replication operator is *, 
    which repeats a list a specified number of times to create a new list.

    
## 10. What is difference between the list methods append() and insert()?

Ans-.The append() method adds an element to the end of the list, while the insert() method adds an element at a specified index,
    shifting existing elements to the right.



## 11. What are the two methods for removing items from a list?

Ans-.The two methods for removing items from a list are remove() and pop(). 
    The remove() method removes the first occurrence of a specified value, 
    while the pop() method removes an element at a specified index and returns its value.



## 12. Describe how list values and string values are identical.

Ans-.List values and string values are similar in that they are both ordered sequences of values.
    They can be indexed and sliced, and they support many of the same methods, such as len(), min(), and max().However,
    unlike strings, list values can be modified and can contain elements of different types.

    
## 13. What's the difference between tuples and lists?

Ans-.Tuples and lists are both ordered sequences of values, but tuples are immutable while lists are mutable.
    Tuples are defined using parentheses ( ) while lists are defined using square brackets [ ].

## 14. How do you type a tuple value that only contains the integer 42?

Ans-.To create a tuple value that only contains the integer 42, you can use the following code:
    my_tuple = (42,)
    The comma is necessary to differentiate between a tuple and an integer surrounded by parentheses.


## 15. How do you get a list value's tuple form? How do you get a tuple value's list form?

Ans-.To get a list value in tuple form, you can use the tuple() function. For example:
    my_list = [1, 2, 3]
    my_tuple = tuple(my_list)
    To get a tuple value in list form, you can use the list() function. For example:
    my_tuple = (1, 2, 3)
    my_list = list(my_tuple)

    


## 16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?

Ans-.In Python, a variable that "contains" list values can be a reference to a list object, rather than a list itself.
    This means that the variable stores a memory address that points to where the list is stored in memory,rather than the
    list data itself. 


##17. How do you distinguish between copy.copy() and copy.deepcopy()?

Ans-.In Python copy module, copy.copy() and copy.deepcopy() are both used to create copies of objects. However,
    they differ in how they handle nested objects (e.g. lists within lists).
    copy.copy() creates a shallow copy of an object, which means that it creates a new object with a new memory address,
    but the nested objects within the original object are still referenced by the new object. 
    This can be illustrated with an example:
       
    import copy
    list_a = [1, [2, 3]]
    list_b = copy.copy(list_a)

    list_a[1].append(4)
    print(list_b)  # Output: [1, [2, 3, 4]]
    
    n this case, list_b is a shallow copy of list_a, so when we modify the nested list within list_a,
    the change is also reflected in list_b
    
    copy.deepcopy() creates a deep copy of an object, which means that it creates a new object with new memory 
    addresses for all of the nested objects within the original object. This can be illustrated with an example:
    import copy

    list_a = [1, [2, 3]]
    list_b = copy.deepcopy(list_a)

    list_a[1].append(4)
    print(list_b)  # Output: [1, [2, 3]]
    
    In this case, list_b is a deep copy of list_a, so when we modify the nested list within list_a,
    the change is not reflected in list_b.
