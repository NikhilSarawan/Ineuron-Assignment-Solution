# %%
##1. What is the result of the code, and explain?


>>> X = 'iNeuron'
>>> def func():
print(X)


>>> func()

Ans-.The code defines a variable X and assigns it the value of the string 'iNeuron'. Then, it defines a function func that,
    does nothing except print the value of X. Finally, it calls the func function.

    The expected output of this code is the string 'iNeuron', since that is the value of the X variable that is printed,
    by the func function. When the func function is called, it prints the value of X, which is 'iNeuron', to the console.

    In other words, this code demonstrates that a function can access variables defined outside of its own scope. 
    Because X is defined outside of the func function, the func function is able to print its value even though it,
    was not passed in as an argument.


##2. What is the result of the code, and explain?


>>> X = 'iNeuron'
>>> def func():
X = 'NI!'


>>> func()
>>> print(X)

Ans-.The code defines a variable X and assigns it the value of the string 'iNeuron'. Then, it defines a function func that,
    creates a new local variable X and assigns it the value of the string 'NI!'. Finally, it calls the func function and,
    prints the value of the X variable to the console.

    The expected output of this code is the string 'iNeuron', because the print statement comes after the func call and is,
    therefore not affected by the new local variable X that is created inside the func function.

    When the func function is called, it creates a new variable X that is local to the function and has no effect on the ,
    value of the global variable X. Therefore, when the print statement is executed, it prints the value of the global ,
    variable X, which is still 'iNeuron'.

    In other words, this code demonstrates that a function can create a new variable with the same name as a variable defined,
    outside of its own scope, without affecting the value of the global variable. This is because the local variable only,
    exists within the scope of the function and does not affect the value of the global variable.

##3. What does this code print, and why?


>>> X = 'iNeuron'
>>> def func():
X = 'NI'
print(X)


>>> func()
>>> print(X)

Ans-.he code defines a variable X and assigns it the value of the string 'iNeuron'. Then,
    it defines a function func that creates a new local variable X and assigns it the value of the string 'NI', 
    and then prints the value of this local variable to the console. Finally, it calls the func function and prints,
    the value of the global variable X to the console.

    The expected output of this code is:
    NI
    iNeuron
    
    When the func function is called, it creates a new variable X that is local to the function and has no effect on,
    the value of the global variable X. Therefore, when the print statement inside the function is executed, 
    it prints the value of the local variable X, which is 'NI'.

    When the print statement outside the function is executed, it prints the value of the global variable X, 
    which is still 'iNeuron'.
    
    In other words, this code demonstrates that a local variable created inside a function with the same name ,
    as a global variable does not affect the value of the global variable outside of the function. 
    The local variable is only visible inside the function, while the global variable is visible throughout the entire program.

##4. What output does this code produce? Why?


>>> X = 'iNeuron'
>>> def func():
global X
X = 'NI'


>>> func()
>>> print(X)

Ans-.The code defines a variable X and assigns it the value of the string 'iNeuron'. Then, it defines a function func that,
    declares the global variable X inside the function and assigns it the value of the string 'NI'. Finally, it calls the func,
    function and prints the value of the global variable X to the console.

    The expected output of this code is the string 'NI', because the func function explicitly declares X to be a global ,
    variable and assigns it the value of 'NI'. Therefore, when the print statement is executed, it prints the value of ,
    the global variable X, which has been changed inside the func function.

    In other words, this code demonstrates that a function can modify the value of a global variable by declaring the,
    variable as global inside the function. This allows the function to access and modify the value of the global variable, 
    which can then be seen outside of the function as well.

##5. What about this code—what’s the output, and why?


>>> X = 'iNeuron'
>>> def func():
X = 'NI'
def nested():
print(X)
nested()


>>> func()
>>> X

Ans-.The code defines a variable X and assigns it the value of the string 'iNeuron'. Then, it defines a function func that,
    creates a new local variable X and assigns it the value of the string 'NI'. Inside the func function, it defines another,
    function nested that prints the value of the local variable X to the console. Finally, it calls the nested function and ,
    then calls func, and prints the value of the global variable X to the console.

    The expected output of this code is
    
    NI
    iNeuron
    
    When the nested function is called, it prints the value of the local variable X that was defined in the parent,
    func function, which is 'NI'.

    When the func function is called, it defines a new local variable X that is different from the global variable X.
    Then, it calls the nested function, which prints the value of the local variable X to the console. After that,
    the func function finishes executing and returns, so the local variable X is destroyed and has no effect on the ,
    value of the global variable X.

    Finally, when the print statement outside the function is executed, it prints the value of the global variable X,
    which is still 'iNeuron'.

    In other words, this code demonstrates that a nested function can access the variables defined in its parent function,
    even if the parent function has finished executing and its local variables have been destroyed. However, 
    the local variables defined in the parent function do not affect the value of the global variables.

##6. How about this code: what is its output in Python 3, and explain?


>>> def func():
X = 'NI'
def nested():
nonlocal X
X = 'Spam'
nested()
print(X)


>>> func()

Ans-.The code defines a function func that creates a local variable X and assigns it the value of the string 'NI'.
    Inside the func function, it defines another function nested that declares the variable X as nonlocal and assigns it,
    the value of the string 'Spam'. Then, it calls the nested function and prints the value of the variable X to the console.

    The expected output of this code is 'Spam', because the nested function modifies the nonlocal variable X to be 'Spam',
    and this change is reflected outside of the nested function when func calls the print statement.

    The nonlocal keyword allows nested functions to modify variables in their parent functions. In this case, the nested,
    function modifies the nonlocal variable X that was defined in the parent function func. This change persists after the ,
    nested function returns, so when the print statement is executed, it prints the modified value of X.

    Note that this code will raise a SyntaxError if executed in Python 2, because the nonlocal keyword is not available in,
    Python 2.
