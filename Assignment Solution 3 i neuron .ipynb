# %%
##  1. Why are functions advantageous to have in your programs?

Ans-.Functions are advantageous to have in your programs because they allow you to break down complex tasks into smaller,
    more manageable pieces of code. This makes your code easier to understand, debug, and maintain. Functions also promote code
    reuse, as you can call the same function multiple times throughout your program with different arguments.
    
    
##  2. When does the code in a function run: when it's specified or when it's called?

Ans-.The code in a function runs when it is called, not when it is specified. When you call a function,
     the program jumps to the function definition and executes the code within it.
    
##  3. What statement creates a function? 

Ans-.The statement that creates a function in Python is "def". For example, 
     the following code creates a function called "add_numbers" that takes two arguments and returns their sum: 
     def add_numbers(x, y):
     return x + y

##  4. What is the difference between a function and a function call?

Ans-.A function is a block of code that performs a specific task, while a function call is the code that requests the ,
     execution of a function with specific arguments.In other words, a function call is how you use a function in your program.
    
##  5. How many global scopes are there in a Python program? How many local scopes?

Ans-.There is only one global scope in a Python program, which is where variables that are defined outside of functions reside.
    Local scopes are created whenever a function is called and are destroyed when the function returns. 
    So the number of local scopes depends on how many functions are called in your program.
    
##  6. What happens to variables in a local scope when the function call returns?

Ans-.When a function call returns, variables in the local scope are destroyed and their values are lost.
     Any variables that were defined in the local scope cannot be accessed outside of the function.
    
##  7. What is the concept of a return value? Is it possible to have a return value in an expression? 

Ans-.A return value is the value that a function sends back to the code that called it
     It is possible to have a return value in an expression, which means that you can use the return value of a function as part,
     of a larger expression. For example:
     
     total = add_numbers(2, 3) * 10
    
##  8. If a function does not have a return statement, what is the return value of a call to that function?   
 
Ans-.If a function does not have a return statement, the return value of a call to that function is "None". 
     This is a special value in Python that represents the absence of a value. 

##  9. How do you make a function variable refer to the global variable?

Ans-.To make a function variable refer to a global variable, you can use the "global" keyword inside the function.
     For example:
     x = 10

    def my_function():
    global x
    x = 20

    my_function()
    print(x) 
    
## 10. What is the data type of None? 

Ans-.The data type of "None" is "NoneType". It is a built-in data type in Python that represents the absence of a value.

## 11. What does the sentence import areallyourpetsnamederic do?

Ans-.The sentence "import areallyourpetsnamederic" is not a valid Python statement and would result in a syntax error.

## 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

Ans-.If you had a "bacon()" feature in a "spam" module, you would call it like this after importing "spam":
    
    import spam

    spam.bacon()

    
## 13. What can you do to save a programme from crashing if it encounters an error?

Ans-.To save a program from crashing if it encounters an error, you can use error handling with a "try" and "except" block.
    This allows you to catch and handle errors gracefully instead of letting them crash the program.
    
## 14. What is the purpose of the try clause? What is the purpose of the except clause? 

Ans-.The purpose of the "try" clause is to enclose code that may raise an error.
    The purpose of the "except" clause is to specify the code that should be executed if an error is raised within,
    the "try" clause. The "except" clause allows you to catch and handle specific types of errors, 
    or to catch all errors using a general exception.
