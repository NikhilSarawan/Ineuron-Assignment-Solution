# %%
##1. Create a zoo.py file first. Define the hours() function, which prints the string 'Open 9-5 daily'. Then,
     #use the interactive interpreter to import the zoo module and call its hours() function.

Ans-.To create a zoo.py file, open a text editor and type the following code:
    def hours():
    print('Open 9-5 daily')
    
    Save the file as zoo.py in a directory of your choice.

    To use the interactive interpreter, open a terminal or command prompt, navigate to the directory where zoo.py is saved,
    and type python to start the Python interpreter. Then, type the following commands:
        
    import zoo
    zoo.hours()
    
    This should output the string "Open 9-5 daily" to the console.




##2. In the interactive interpreter, import the zoo module as menagerie and call its hours() function.

Ans-.As the code was already executed in the previous question, we can simply run the following code in the interactive,
    interpreter to import the zoo module as menagerie and call its hours() function:
    
    import zoo as menagerie
    menagerie.hours()

    This should print the output: Open 9-5 daily.

##3. Using the interpreter, explicitly import and call the hours() function from zoo.

Ans-.from zoo import hours

    hours()
    
    This will import the hours() function from the zoo module and call it, printing the string 'Open 9-5 daily'.



##4. Import the hours() function as info and call it.

Ans-.Here is how you can import the hours() function as info and call it:

    from zoo import hours as info

    info()

    This will call the hours() function from the zoo module but it will be referred to as info in the current namespace.





##5. Create a plain dictionary with the key-value pairs 'a': 1, 'b': 2, and 'c': 3, and print it out.

Ans-.Here is how you can create a plain dictionary with the given key-value pairs and print it out:
    
    # create the dictionary
    my_dict = {'a': 1, 'b': 2, 'c': 3}

    # print the dictionary
    print(my_dict)
    
    This will output:

    {'a': 1, 'b': 2, 'c': 3}


##6.Make an OrderedDict called fancy from the same pairs listed in 5 and print it. Did it print in the same order as plain?

Ans-.No, it printed in the same order as the order in which the keys were added. OrderedDict remembers the order in which items were added, whereas a regular dictionary does not. 
    Here is an example code snippet to create an OrderedDict and print it:
        
    from collections import OrderedDict

    # Create an OrderedDict
    fancy = OrderedDict([('a', 1), ('b', 2), ('c', 3)])

    # Print the OrderedDict
    print(fancy)

    This will output:

    OrderedDict([('a', 1), ('b', 2), ('c', 3)])


##7. Make a default dictionary called dict_of_lists and pass it the argument list. Make the list dict_of_lists['a'] and,
    #append the value 'something for a' to it in one assignment. Print dict_of_lists['a'].

Ans-.Here is the code to make a default dictionary called dict_of_lists, append a value to the list for key 'a', 
    then print the list for key 'a':
        
    from collections import defaultdict

    dict_of_lists = defaultdict(list)
    dict_of_lists['a'].append('something for a')
    print(dict_of_lists['a'])
    
    Output:
        
    ['something for a']
