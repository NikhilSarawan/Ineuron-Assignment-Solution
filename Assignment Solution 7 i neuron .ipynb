# %%
##1. What is the name of the feature responsible for generating Regex objects?

Ans-.The feature responsible for generating Regex objects is the re module in Python. The re module provides a set of functions,
    and methods for working with regular expressions, including the re.compile() function, which generates a Regex object.Here,
    is an example of using re.compile() to create a Regex object:
    
    import re

    pattern = re.compile(r'\d{3}-\d{3}-\d{4}')
    
    In this example, re.compile() is used to create a Regex object that matches a phone number in the format of xxx-xxx-xxxx. 
    The r before the pattern string indicates that it should be treated as a raw string, allowing backslashes to be interpreted,
    as literal backslashes.

    Once you have a Regex object, you can use its methods to search for matches in strings, extract matching substrings,
    and more. The re module is a powerful tool for working with text data in Python.

##2. Why do raw strings often appear in Regex objects?

Ans-.Raw strings often appear in Regex objects because they allow backslashes to be treated as literal backslashes instead of 
    escape characters. Since regular expressions often contain a lot of backslashes, it can be cumbersome to escape them all
    manually. Using a raw string makes it easier to write and read regular expressions.

    Here's an example to illustrate the point. Let is say we want to match a backslash followed by a digit:
        import re

        Using a regular string
        pattern1 = re.compile("\\\d")

        Using a raw string
        pattern2 = re.compile(r"\\d")
        
        
    In pattern1, we need to use two backslashes to match a single backslash because the first backslash is an escape character
    that must be escaped itself. In pattern2, we use a raw string and only need to use a single backslash to match a backslash 
    followed by a digit.

    Using raw strings in regular expressions can make them more readable and less error-prone, especially when dealing
    with complex patterns that contain many backslashes.

##3. What is the return value of the search() method?

Ans-.The search() method is a method of a compiled Regex object in Python's re module. It searches the given input string for 
    the first occurrence of the regular expression pattern, and returns a Match object if a match is found, otherwise it
    returns None.

    The Match object contains information about the matched substring, including the starting and ending indices of the match,
    as well as the matched substring itself.

    Here's an example of using the search() method:
    
    import re

    pattern = re.compile(r'\d+')
    match = pattern.search('I have 2 cats and 3 dogs.')

    if match:
    print('Match found:', match.group())
    else:
    print('No match found.')

    in this example, the regular expression \d+ matches one or more digits. The search() method is used to search the input
    string 'I have 2 cats and 3 dogs.' for the first occurrence of the pattern. Since there are digits in the input string,
    the method returns a Match object.

    The if match: statement checks if a match was found, and if so, the group() method is called on the Match object to get
    the matched substring. In this case, it prints 'Match found: 2'.

    If the pattern is not found in the input string, the search() method returns None, indicating that no match was found.

    Note that the search() method only finds the first match in the input string. If you want to find all matches, 
    you can use the findall() method instead.

##4. From a Match item, how do you get the actual strings that match the pattern?

Ans-.Once you have obtained a Match object using the search() method of a compiled regular expression, you can use the group()
    method to get the actual string that matched the pattern.The group() method returns the entire match by default,
    but you can also specify a group number to get a specific group. Groups are defined using parentheses in the regular,
    expression pattern.

    Here's an example:
    import re

    pattern = re.compile(r'(\d{3})-(\d{3}-\d{4})')
    match = pattern.search('My phone number is 123-456-7890.')

    if match:
    print('Full match:', match.group())         # '123-456-7890'
    print('Area code:', match.group(1))         # '123'
    print('Phone number:', match.group(2))      # '456-7890'
    else:
    print('No match found.')
    
    In this example, the regular expression pattern \d{3}-\d{3}-\d{4} matches a phone number in the format of '###-###-####'. The pattern is grouped using parentheses to define two groups - the area code and the phone number.

    The search() method is used to search the input string 'My phone number is 123-456-7890.' for the phone number pattern.
    Since there is a phone number in the input string, the method returns a Match object.The if match: statement checks if a,
    match was found, and if so, the group() method is called on the Match object to get the entire matched substring.
    In this case, it prints 'Full match: 123-456-7890'.

    The group(1) method is called on the Match object to get the area code (the first group defined by the parentheses in the,
    pattern). In this case, it prints 'Area code: 123'.

    The group(2) method is called on the Match object to get the phone number (the second group defined by the parentheses in,
    the pattern). In this case, it prints 'Phone number: 456-7890'.

    Note that if there are no groups defined in the regular expression pattern, you can still use the group(),
    method to get the entire matched substring. In that case, calling group(0) is equivalent to calling group().








##5. In the regex which created from the r'(\d\d\d)-(\d\d\d-\d\d\d\d)', what does group zero cover? Group 2? Group 1?

Ans-.The regular expression r'(\d\d\d)-(\d\d\d-\d\d\d\d)' defines two groups using parentheses.

    Group 1: (\d\d\d) matches three consecutive digits before a hyphen.
    Group 2: (\d\d\d-\d\d\d\d) matches a string with a hyphen separating three digits followed by another hyphen and four more ,
            digits.
    Group 0 refers to the entire matched string, including any groups. In this case, group 0 covers the entire phone number in,
            the format of '###-###-####'.

    Here isan example to illustrate this:
        
    import re

    pattern = re.compile(r'(\d\d\d)-(\d\d\d-\d\d\d\d)')
    match = pattern.search('My phone number is 123-456-7890.')

    if match:
    
    print('Full match:', match.group())         # '123-456-7890'
    print('Group 0:', match.group(0))           # '123-456-7890'
    print('Group 1:', match.group(1))           # '123'
    print('Group 2:', match.group(2))           # '456-7890'
    
    else:
    print('No match found.')
    
    
    In this example, the regular expression pattern \d\d\d-\d\d\d-\d\d\d\d matches a phone number in the format of '###-###-####'. The pattern is grouped using parentheses ,
    to define two groups - the area code and the phone number.

    The search() method is used to search the input string 'My phone number is 123-456-7890.' for the phone number pattern.
    Since there is a phone number in the input string, the method returns a Match object.

    The if match: statement checks if a match was found, and if so, the group() method is called on the Match object to get the,
    entire matched substring. In this case, it prints 'Full match: 123-456-7890'.

    The group(0) method is called on the Match object to get the entire matched substring. In this case, it prints 'Group 0: 
    123-456-7890', which is the same as calling group().

    The group(1) method is called on the Match object to get the area code (the first group defined by the parentheses in the,
    pattern). In this case, it prints 'Group 1: 123'.

    The group(2) method is called on the Match object to get the phone number (the second group defined by the parentheses in, 
    the pattern). In this case,it prints 'Group 2: 456-7890'.
    
##6. In standard expression syntax, parentheses and intervals have distinct meanings. How can you tell a regex that you want 
     #,it to fit real parentheses and periods?

Ans-.The findall() method in Python re module returns either a list of strings or a list of tuples depending on whether the ,
    regular expression pattern contains capturing groups or not.

    If the pattern contains no capturing groups, then findall() returns a list of strings representing all non-overlapping 
    matches,of the pattern in the input string.

    For example, the following code returns a list of strings for the given input:
    

    input_str = "The quick brown fox jumps over the lazy dog"
    pattern = r"\b\w{4}\b" # match four-letter words

    matches = re.findall(pattern, input_str)
    print(matches) # Output: ['quick', 'brown', 'jumps', 'over', 'lazy']
    
    If the pattern contains capturing groups, then findall() returns a list of tuples, where each tuple contains the captured,
    groups for each match.

    For example, the following code returns a list of tuples for the given input:
        
    import re

    input_str = "John Smith, Jane Doe, Alice Johnson"
    pattern = r"(\w+)\s+(\w+)"

    matches = re.findall(pattern, input_str)
    print(matches) # Output: [('John', 'Smith'), ('Jane', 'Doe'), ('Alice', 'Johnson')]
    
    In this example, the pattern matches two words separated by one or more whitespace characters and captures each word as a group.
    The resulting list contains tuples with the captured words for each match.



##7. The findall() method returns a string list or a list of string tuples. What causes it to return one of the two options?

Ans-The findall() method in Pythons re module returns either a list of strings or a list of tuples depending on whether the 
regular expression pattern contains capturing groups or not.

    If the pattern contains no capturing groups, then findall() returns a list of strings representing all non-overlapping
    matches of the pattern in the input string.

    For example, the following code returns a list of strings for the given input:

    python
    Copy code
    import re

    input_str = "The quick brown fox jumps over the lazy dog"
    pattern = r"\b\w{4}\b" # match four-letter words

    matches = re.findall(pattern, input_str)
    print(matches) # Output: ['quick', 'brown', 'jumps', 'over', 'lazy']
    If the pattern contains capturing groups, then findall() returns a list of tuples, 
    where each tuple contains the captured groups for each match.

    For example, the following code returns a list of tuples for the given input:

    python
    Copy code
    import re

    input_str = "John Smith, Jane Doe, Alice Johnson"
    pattern = r"(\w+)\s+(\w+)"

    matches = re.findall(pattern, input_str)
    print(matches) # Output: [('John', 'Smith'), ('Jane', 'Doe'), ('Alice', 'Johnson')]
    In this example, the pattern matches two words separated by one or more whitespace characters and captures each word as a group. The resulting list contains tuples with the captured words for each match.
    


##8. In standard expressions, what does the | character mean?

Ans-..In standard regular expressions, the | character is known as the alternation or OR operator.
    It allows you to match either one pattern or another pattern.For example, the regular expression cat|dog,
    matches either the string "cat" or the string "dog". If the input string contains both "cat" and "dog", 
    the regex will match the first occurrence of either one.

    Here's an example Python code that uses the | operator to match either "cat" or "dog":
    
    import re

    input_str = "I have a cat and a dog"
    pattern = r"cat|dog"

    matches = re.findall(pattern, input_str)
    print(matches) # Output: ['cat', 'dog']
    In this example, the findall() method returns a list of all matches found in the input string. 
    Since the input string contains both "cat" and "dog", the resulting list contains both strings in the order they were found.

##9. In regular expressions, what does the character stand for?

Ans-.In regular expressions, the . character (period or dot) is known as the dot metacharacter, which matches any single
    character except a newline.For example, the regular expression a.b matches any three-character string that starts with "a",
    ends with "b", and has any single character in between "a" and "b". So it would match "acb", "aab", "a1b", "a b", and so on.

    Here's an example Python code that uses the . metacharacter to match a three-letter word that starts with "a" and ends,
    with "t":

    import re

    input_str = "I have a cat and a hat, but not a bat or a mat"
    pattern = r"a.t"

    matches = re.findall(pattern, input_str)
    print(matches) # Output: ['cat', 'hat']
    
    In this example, the findall() method returns a list of all matches found in the input string. The .
    metacharacter matches any single character in between "a" and "t".



##10.In regular expressions, what is the difference between the + and * characters?

Ans-.In regular expressions, the + and * characters are used to specify the number of occurrences of the preceding
    character or group.The + character matches one or more occurrences of the preceding character or group. 
    For example, the regular expression "ab+" matches the string "ab" followed by one or more occurrences of the letter "b",
    such as "abb", "abbb", "abbbb", and so on.The * character matches zero or more occurrences of the preceding character or
    group. For example, the regular expression "ab*" matches the string "a" followed by zero or more occurrences of the letter
    "b", such as "a", "ab", "abb", "abbb", and so on. So, the main difference is that + requires at least one occurrence of the
    preceding character or group, while * does not require any occurrence.

##11. What is the difference between {4} and {4,5} in regular expression?

Ans-.In regular expressions, the symbols {} are used to indicate the number of times a pattern should be repeated.

    The notation {4} means that the preceding pattern should be repeated exactly four times. For example, 
    the regular expression "a{4}" matches the string "aaaa", but not "aa" or "aaaaa".

    On the other hand, the notation {4,5} means that the preceding pattern should be repeated at least four times,
    but no more than five times. For example, the regular expression "a{4,5}" matches the strings "aaaa" and "aaaaa",
    but not "aa" or "aaaaaa".

    So the main difference between {4} and {4,5} is that {4} requires the pattern to be repeated exactly four times, 
    while {4,5} allows it to be repeated four or five times.

    For example, the regular expression "x{4}" would match "xxxx" but not "xxx" or "xxxxx", 
    while the regular expression "y{4,5}" would match "yyyy" and "yyyyy" but not "yyy" or "yyyyyy".

##12. What do you mean by the \d, \w, and \s shorthand character classes signify in regular expressions?

Ans-.In regular expressions, shorthand character classes are special symbols that represent certain sets of characters. These shorthand character classes can be used to match patterns that are commonly found in text data.

    The following are the most common shorthand character classes:

    \d - Matches any digit character. This is equivalent to the character class [0-9]. For example, 
    the regular expression \d+ matches one or more digits. So, it would match "123" or "4567", but not "abc".

    \w - Matches any word character, which includes letters, digits, and underscores. 
    This is equivalent to the character class [a-zA-Z0-9_]. For example, the regular expression \w+ matches one or more word 
    characters. So, it would match "hello", "world_123", but not "hello!".

    \s - Matches any whitespace character, such as a space, tab, or newline.
    This is equivalent to the character class [ \t\n\r\f\v]. For example, the regular expression \s+ matches one or more whitespace characters. So, it would match " ", " \t\r\n", but not "hello".

    Here are some examples of using shorthand character classes:

    The regular expression \d{3}-\d{2}-\d{4} matches a Social Security Number (SSN) in the format of "123-45-6789".
    The regular expression \w+@\w+\.\w{2,3} matches an email address in the format of "example123@example.com".
    The regular expression (\s?\d{3}){3}\s? matches a phone number in the format of "123 456 7890" or "1234567890".

##13. What do means by \D, \W, and \S shorthand character classes signify in regular expressions?

Ans-.In regular expressions, shorthand character classes are used to represent certain groups of characters. 
    These shorthand character classes make it easier to match specific types of characters in a given string.

    Here are the explanations and examples of the \D, \W, and \S shorthand character classes:

    \D: This shorthand character class represents any non-digit character. It is equivalent to [^0-9]. 
        For example, the regular expression "a\Dc" will match any string that starts with "a", 
        followed by any non-digit character, and ends with "c". So, it will match "abc", "a#c", but not "a5c".

    \W: This shorthand character class represents any non-word character. It is equivalent to [^a-zA-Z0-9_]. For example, 
        the regular expression "\W+" will match any sequence of one or more non-word characters. So, it will match "!!", "**",
        but not "hello_world".

    \S: This shorthand character class represents any non-whitespace character. It is equivalent to [^\s]. For example,
        the regular expression "\S+" will match any sequence of one or more non-whitespace characters. So,
        it will match "hello", "world", but not "hello world".

    Overall, shorthand character classes are a powerful tool in regular expressions that allow you to match specific types 
    of characters quickly and easily.



##14. What is the difference between .*? and .*?

Ans-.There seems to be a typo in your question. I'll provide an explanation of the difference between .* and .*? instead.

    In regular expressions, .* is a greedy quantifier that matches zero or more of any character, including newline characters,
    abs as many times as possible. This means that it will match as much of the string as it possibly can.

    For example, the regular expression a.*c applied to the string abbbcabc will match the entire string abbbcabc because the .
    * matches "bbb".

    On the other hand, .*? is a lazy quantifier that matches zero or more of any character, including newline characters,
    as few times as possible. This means that it will match as little of the string as it possibly can.
    
    For example, the regular expression a.*?c applied to the string abbbcabc will only match abc, because the .*?
    matches "nothing" between the a and the b, and then matches the smallest possible sequence of characters until it reaches
    the c.

    So, the main difference between .* and .*? is that .* is greedy and matches as much as possible, while .*? is lazy
    and matches as little as possible.

##15. What is the syntax for matching both numbers and lowercase letters with a character class?

Ans-.To match both numbers and lowercase letters in a regular expression, you can use a character class,
    which is enclosed in square brackets [ ] and contains a list of characters to match.
    Here the syntax to match both numbers and lowercase letters using a character class:[0-9a-z]
    This character class matches any character that is either a number (0-9) or a lowercase letter (a-z). 
    The hyphen - indicates a range of characters, so [0-9a-z] is equivalent to writing [0123456789abcdefghijklmnopqrstuvwxyz].

    Here are some examples of how to use this character class in regular expressions:

    The regular expression ^[0-9a-z]+$ matches a string that contains only numbers and lowercase letters,
    with no spaces or other characters. For example, it would match "abc123", but not "ABC123" or "abc 123".

    The regular expression [0-9a-z]+@[a-z]+\.[a-z]+ matches an email address that contains only lowercase letters and
    numbers in the username and lowercase letters in the domain. For example, it would match "john@example.com",
    but not "JohnDoe@example.com" or "john.doe@example.com".

    Overall, using a character class is a powerful tool in regular expressions that allows you to match a specific
    set of characters quickly and easily.

##16. What is the procedure for making a normal expression in regax case insensitive?

Ans-.To make a regular expression case insensitive, you can use a flag or modifier that is supported by most programming,
    languages and regular expression engines. Here are the general steps to make a regular expression case insensitive:

    Identify the regular expression pattern that you want to make case insensitive.
    This could be any pattern that contains letters or words that can be matched regardless of their case.

    Add the case-insensitive flag to the regular expression. The specific syntax for adding the flag may vary depending,
    on the programming language or regular expression engine that you are using. In most cases,
    you can add the flag as a modifier after the closing delimiter of the regular expression.

    Test the modified regular expression to make sure it matches the desired strings regardless of case. 
    You can use a variety of test strings with different cases to check that the regular expression is functioning correctly.
    
    Python: You can add the re.IGNORECASE flag as a second argument when compiling the regular expression with the re.compile()
    function.For example, the regular expression re.compile('hello', re.IGNORECASE) will match "Hello", "HELLO",
    and "hello" equally.


##17. What does the . character normally match? What does it match if re.DOTALL is passed as 2nd argument in re.compile()?

Ans-.In a regular expression, the . (dot) character normally matches any single character except for a newline character (\n).
    For example, the regular expression a.b would match "acb", "a#b", "a b", and so on, as long as there is a single character
    between the "a" and the "b".

    If the re.DOTALL flag is passed as the second argument to re.compile(), then the dot character . matches any character
    including the newline character \n. This means that the regular expression a.b with the re.DOTALL flag would match "a\nb" as
    well as any other string that has "a" followed by any character, followed by "b", even if the character is a newline.

    Here's an example in Python to illustrate the difference. Let's say we have a string with multiple lines:
         text = "hello\nworld\n"
    We can use the regular expression h.llo to match "hello" in the string, but it won't match "hel\nlo" because the
    newline character \n is between "el" and "lo". However,if we use the re.DOTALL flag with the regular expression, like this:
        import re

    pattern = re.compile('h.llo', re.DOTALL)
    match = pattern.search(text)
    Now the dot character . matches any character, including the newline character \n,
    so the regular expression will match "hel\nlo" as well as "hello".

    Overall, the re.DOTALL flag can be useful when you want to match a pattern that includes newline characters,
    such as when you're working with multiline text.
    



##18. If numReg = re.compile(r'\d+'), what will numRegex.sub('X', '11 drummers, 10 pipers, five rings, 4 hen') return?

Ans-.If numRegex = re.compile(r'\d+'), then numRegex.sub('X', '11 drummers, 10 pipers, five rings, 4 hen') will return the string:
    'X drummers, X pipers, five rings, X hen'
    Here's how the regular expression substitution works:

    The regular expression \d+ matches one or more digits in the input string.
    The sub() method replaces each match of the regular expression with the string 'X'.
    In the input string '11 drummers, 10 pipers, five rings, 4 hen', the regular expression matches the substrings '11', '10',
    and '4'.Each match of the regular expression is replaced with the string 'X', resulting in the new string 'X drummers,
    X pipers, five rings, X hen'.So the final result is a new string where all the digit sequences have been replaced with,
    the letter 'X'.

##19. What does passing re.VERBOSE as the 2nd argument to re.compile() allow to do?

Ans-.Passing re.VERBOSE as the second argument to re.compile() in Python allows you to create a regular expression pattern
    with whitespace and comments, without affecting the matching behavior of the pattern.

    Normally, whitespace characters (spaces, tabs, and newlines) in a regular expression pattern are significant and can affect 
    the matching behavior. This can make it difficult to write and read complex regular expressions with many parts.

    The re.VERBOSE flag allows you to use whitespace and comments in the regular expression pattern to improve its readability,
    without affecting the way the pattern matches. Here's an example:
    
    import re

    pattern = re.compile(r"""
    \d+         # match one or more digits
    [ ]?        # optionally match a space
    (inches|cm) # match either 'inches' or 'cm'
    """, re.VERBOSE)

    match = pattern.search('The box is 10 cm wide')
    print(match.group(0))  # output: '10 cm'
    
    In this example, the regular expression pattern matches a number followed by either "inches" or "cm", 
    optionally separated by a space. The re.VERBOSE flag allows us to use comments and whitespace to make the
    pattern more readable.

    Without the re.VERBOSE flag, the pattern would have to be written without whitespace and comments, like this:
    pattern = re.compile(r'\d+[ ]?(inches|cm)')
    
    Using the re.VERBOSE flag can make it easier to write and read complex regular expressions,
    especially when they have many parts or require complicated logic.

##20. How would you write a regex that match a number with comma for every three digits? It must match the given following:
    #'42'
    #'1,234'
    #'6,368,745'

Ans-.You can use the following regular expression to match a number with commas for every three digits
    ^\d{1,3}(,\d{3})*$
    This regular expression matches a string that starts with 1-3 digits (\d{1,3}), 
    followed by zero or more occurrences of a comma and three digits ((,\d{3})*).
    The ^ and $ anchors at the beginning and end of the pattern ensure that the entire string matches the pattern.

    Here's how you can use this regular expression in Python to match the examples you provided:
    import re

    pattern = re.compile(r'^\d{1,3}(,\d{3})*$')

    match1 = pattern.match('42')
    match2 = pattern.match('1,234')
    match3 = pattern.match('6,368,745')

    print(bool(match1))  # True
    print(bool(match2))  # True
    print(bool(match3))  # True
    
    import re

    pattern = re.compile(r'^\d{1,3}(,\d{3})*$')

    match1 = pattern.match('42')
    match2 = pattern.match('1,234')
    match3 = pattern.match('6,368,745')

    print(bool(match1))  # True
    print(bool(match2))  # True
    print(bool(match3))  # True

    All three examples match the regular expression pattern and return True.

    Note that this regular expression only matches numbers with commas every three digits.
    It does not allow for decimal places or negative numbers. If you need to match numbers with decimal,
    places or negative numbers,you may need to modify the regular expression pattern accordingly.
