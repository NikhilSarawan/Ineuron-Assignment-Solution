# %%
##1. Create an assert statement that throws an AssertionError if the variable spam is a negative integer.

Ans-.Here is an example of an assert statement that throws an AssertionError if the variable spam is a negative integer:
    
    assert spam >= 0, "spam must be a non-negative integer"
    
    In this statement, we're checking that spam is greater than or equal to zero.
    If it is not, an AssertionError will be raised with the message "spam must be a non-negative integer".
    This is a way to catch programming errors early on, so that we can identify and fix them quickly.

##2. Write an assert statement that triggers an AssertionError if the variables eggs and bacon contain strings that are the,
    #same as each other, even if their cases are different (that is, 'hello' and 'hello' are considered the same, and 'goodbye',
    #and 'GOODbye' are also considered the same).

Ans-.Here is an example of an assert statement that triggers an AssertionError if the variables eggs and bacon contain strings,
    that are the same as each other, even if their cases are different
    
    assert eggs.lower() != bacon.lower(), "eggs and bacon cannot have the same value (ignoring case)"

    In this statement, we're using the lower() method to convert both eggs and bacon to lowercase before comparing them.
    If the lowercase versions of eggs and bacon are the same, an AssertionError will be raised with the message,
    "eggs and bacon cannot have the same value (ignoring case)".This helps to ensure that the values of eggs and bacon,
    are truly different, regardless of their case.

##3. Create an assert statement that throws an AssertionError every time.

Ans-.Here's an example of an assert statement that throws an AssertionError every time:
    
    assert False, "This assert statement always raises an AssertionError"
    
    In this statement, we are passing False as the first argument, which means that the assertion will always fail and raise,
    an AssertionError. We have also included a custom message that will be displayed with the error. This can be useful for,
    testing and debugging, since it can help us identify where the code is failing.


##4. What are the two lines that must be present in your software in order to call logging.debug()?

Ans-.In order to call logging.debug() in your software, you must first import the logging module and configure it to display,
    debug messages. This typically involves adding two lines to your code:
    
    import logging
    logging.basicConfig(level=logging.DEBUG)

    The first line imports the logging module, which provides the debug() method (as well as other logging methods like info(),
    warning(), and error()).The second line configures the logging module to display debug messages (and messages at higher,
    severity levels, such as info, warning, and error). This is done by calling basicConfig() with the level parameter set to ,
    logging.DEBUG. This means that messages at the DEBUG level and higher will be displayed in the console or log file ,
    (depending on how yo HAve configured logging). With these two lines in place, you can call logging.debug() ,
    (or any other logging method) to log debug messages in your code.

##5. What are the two lines that your program must have in order to have logging.debug() send a logging message to a file named,
    #programLog.txt?

Ans-In order to have logging.debug() send a logging message to a file named "programLog.txt", you need to configure the
    logging module to write messages to a file, in addition to displaying them in the console. This typically involves ,
    adding the following two lines to your code:
    import logging

    # Configure logging to write messages to a file
    logging.basicConfig(filename='programLog.txt', level=logging.DEBUG)

    # Now you can call logging.debug() to log messages to the file
    logging.debug('This is a debug message')
    
    The first line imports the logging module, as usual. The second line configures the logging module to write messages,
    to a file named "programLog.txt", with the level parameter set to logging.DEBUG. This means that messages at the DEBUG,
    level and higher will be written to the file.

    Now, when you call logging.debug(), the message will be logged to both the console and the "programLog.txt" file.


##6.What are the five levels of logging?

Ans-.The logging module in Python supports five levels of logging, in increasing order of severity:

    1.DEBUG: Detailed information for debugging purposes.
    2.INFO: General information about the program's execution.
    3.WARNING: An indication that something unexpected or suspicious has happened, or indicative of some problem that may need,
               attention.
    4.ERROR: An indication that an error has occurred, which is serious enough to warrant attention but not so serious that the,
             program can't continue running.
    5.CRITICAL: A very serious error, indicating that the program may not be able to continue running.
   
    These levels provide a way to filter and prioritize log messages based on their severity. By default,
    the logging module will display messages at the WARNING level and higher,but this can be customized with the basicConfig()
    method, as described in earlier questions.

##7. What line of code would you add to your software to disable all logging messages?

Ans-.In order to disable all logging messages in your software, you can add the following line of code:
    logging.disable(logging.CRITICAL)
    This line of code disables all logging messages at and below the CRITICAL level (which is the highest level of severity).
    This means that no log messages will be displayed in the console or written to log files, regardless of their severity level.

    Note that this line of code should be used with caution, as it effectively silences all logging messages. 
    It should only be used in specific circumstances, such as when you want to suppress all logging output for a particular,
    section of code or when,debugging is complete.

##8.Why is using logging messages better than using print() to display the same message?

Ans-.Using logging messages is better than using print() statements for displaying the same message for several reasons:

    1.Flexibility and configurability: The logging module provides a lot of flexibility and configurability options.
    You can control the format of the messages, the level of severity, the output destination (e.g., console or file), and more.
    This makes it easier to manage and customize your logging output to suit your needs.


    2.Granularity and control: With logging messages, you can control the level of detail that is output to the console or log,
    file. This allows you to separate critical messages from informational or debugging messages, which makes it easier to,
    identify and troubleshoot issues. In contrast, print() statements are typically all-or-nothing: either you see the message ,
    or you don't.

    3.Performance impact: When you use print() statements for debugging, you may forget to remove them when you're done.
    This can lead to a lot of unnecessary output that slows down your program. In contrast, logging messages can be enabled,
    or disabled easily, which allows you to control when and where the messages are displayed. This can help you avoid,
    unnecessary performance impacts.
    
    4.Thread-safety: The logging module is thread-safe, which means that you can use it in multithreaded programs without ,
    worrying about race conditions or other concurrency issues. This is not the case with print() statements, 
    which can cause issues when used in concurrent programs.

    Overall, using logging messages is a more powerful and flexible way to manage and customize your program's output, 
    and it provides more control over the behavior of your program.

##9. What are the differences between the Step Over, Step In, and Step Out buttons in the debugger?

Ans-.The Step Over, Step In, and Step Out buttons in the debugger are used to control the execution of the program and inspect,
    the state of the code. Here are the differences between these buttons:

    1.Step Over: The Step Over button allows you to execute the current line of code and move to the next line, without,
    stepping into any function calls. This is useful when you want to quickly skip over a function call or other code ,
    that you don't need to inspect in detail.

    2.Step In: The Step In button allows you to execute the current line of code and step into any function calls that,
    made on that line. This is useful when you want to inspect the inner workings of a function or method, or ,
    when you suspect that an issue may be occurring within a function call.

    3.Step Out: The Step Out button allows you to execute the remaining lines of the current function and return to the,
    calling code, without stepping through each line individually. This is useful when you have stepped into a function,
    and want to quickly return to the calling code without inspecting each line in detail.

    In summary, Step Over allows you to skip over a line of code or a function call, Step In allows you to step into a ,
    function call and inspect its inner workings, and Step Out allows you to quickly return to the calling code without,
    stepping through each line of the current function.

##10.After you click Continue, when will the debugger stop ?

Ans-.When you click the Continue button in the debugger, the program will resume normal execution and continue running until,
    it either completes normally or encounters another breakpoint or exception.

    If there are no more breakpoints or exceptions encountered, the program will continue running until it either completes,
    all its tasks and exits, or it is interrupted externally (such as by the user pressing Ctrl-C or by an operating system,
    signal).

    In summary, the debugger will not stop again until one of the following events occurs:

    The program reaches another breakpoint
    The program encounters an unhandled exception
    The program completes all its tasks and exits
    The program is interrupted externally

##11. What is the concept of a breakpoint?

Ans-.In software development, a breakpoint is a point in the code where the debugger will pause the execution of the program,
    allowing the developer to inspect the state of the program and step through the code one line at a time.

    Breakpoints are commonly used for debugging purposes, especially when dealing with complex code or hard-to-reproduce bugs.
    They allow developers to examine the internal state of the program at a specific point in time, view the values of variables, 
    and step through the code one line at a time to see how the program executes.

    To set a breakpoint, a developer can usually simply click on the line of code where they want the program to pause.
    When the program reaches that line, it will pause and wait for the developer to inspect the state of the program and step ,
    through the code.

    In summary, breakpoints allow developers to pause the execution of the program at a specific point in the code, and inspect,
    the state of the program, including variable values, memory locations, and other important information.
    This helps developers,identify and fix bugs in their code.
