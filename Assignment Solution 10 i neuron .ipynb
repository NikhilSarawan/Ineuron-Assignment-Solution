# %%
##1. How do you distinguish between shutil.copy() and shutil.copytree()?

Ans-.shutil.copy() and shutil.copytree() are both functions in Python's shutil module used to copy files and directories. 
    The main difference between these two functions is that shutil.copy() is used to copy a single file from one location,
    to another while shutil.copytree() is used to copy an entire directory and all its contents recursively.

    Here are some examples to illustrate the differences:

    Using shutil.copy()

    To copy a single file using shutil.copy(), you can do the following:
    import shutil

    # specify the source and destination paths for the file to be copied
    src_path = '/path/to/source/file.txt'
    dst_path = '/path/to/destination/'

    # use shutil.copy() to copy the file
    shutil.copy(src_path, dst_path)
    
    This will copy the file file.txt from the source directory to the destination directory.

    Using shutil.copytree()
    
    To copy an entire directory and all its contents recursively using shutil.copytree(), you can do the following:
    import shutil

    # specify the source and destination paths for the directory to be copied
    src_path = '/path/to/source/directory/'
    dst_path = '/path/to/destination/'

    # use shutil.copytree() to copy the entire directory
    shutil.copytree(src_path, dst_path)
    
    This will copy the entire source directory and all its contents to the destination directory.
    Note that if the destination directory already exists, shutil.copytree() will raise a FileExistsError.

    In summary, shutil.copy() is used to copy a single file, while shutil.copytree() is used to copy an entire directory,
    and all its contents recursively.
  
    

##2. What function is used to rename files??

Ans-.In Python, the os.rename() function is used to rename files or directories. This function takes two arguments - 
    the current name of the file or directory, and the new name that you want to give it.

    Here's an example of how to use os.rename() to rename a file:
    
    import os

    # specify the current and new file names
    current_name = 'old_file_name.txt'
    new_name = 'new_file_name.txt'

    # use os.rename() to rename the file
    os.rename(current_name, new_name)

    This will rename the file old_file_name.txt to new_file_name.txt. Note that if the file with the new name,
    already exists in the directory, os.rename() will replace it with the renamed file.

    You can also use os.rename() to move a file to a different directory by specifying the full path of the new,
    location in the new name argument. For example:
        
    import os

    # specify the current file path and the new directory path
    current_path = '/path/to/current/file.txt'
    new_path = '/path/to/new/directory/new_file_name.txt'

    # use os.rename() to move the file to the new directory and give it a new name
    os.rename(current_path, new_path)
    
    This will move the file file.txt from its current location to the directory /path/to/new/directory and rename,
    it as new_file_name.txt.

    In summary, the os.rename() function is used to rename files or directories in Python.
  
        
##3. What is the difference between the delete functions in the send2trash and shutil modules?

Ans-.The send2trash and shutil modules are both used for deleting files and directories in Python,
    but they have some differences in their functionalities and behaviors.

    The send2trash module provides a cross-platform implementation of sending files to the operating system is,
    trash or recycle bin instead of permanently deleting them. This allows the user to recover deleted files if needed, 
    similar to how the "move to trash" function works in most graphical user interfaces. The send2trash module provides,
    a single function send2trash.send2trash() that takes a file or directory path as an argument and sends it to the trash ,
    or recycle bin, depending on the operating system.

    On the other hand, the shutil module provides more low-level file and directory operations, including copying, moving, 
    and deleting files and directories. The shutil module provides several functions for deleting files and directories,
    including shutil.rmtree() for deleting directories and their contents recursively, and os.remove() for deleting individual,
    files. These functions delete files and directories permanently and do not send them to the operating system is trash or,
    recycle bin.

    In summary, the main difference between the delete functions in send2trash and shutil is that send2trash sends files to ,
    the operating system is trash or recycle bin, while shutil deletes files and directories permanently.



##4.ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is equivalent,
    #,to File objects’ open() method?

Ans-.ZipFile objects are used to read and manipulate ZIP archives in Python. Similar to File objects,
    ZipFile objects have a close() method that should be called when you are finished working with the archive,
    to free up any resources used by the object.

    The equivalent ZipFile method to File objects' open() method is ZipFile() itself.
    You can create a ZipFile object and open a ZIP archive for reading or writing by passing the archive is
    filename as a string argument to the ZipFile() constructor. For example, to open a ZIP archive named "example.zip" 
    for reading, you can use the following code:
        
    import zipfile

    with zipfile.ZipFile('example.zip', 'r') as myzip:
    # work with the contents of the archive
    In this example, ZipFile() is used to open the "example.zip" archive for reading ('r'). 
    The resulting ZipFile object is assigned to the variable myzip, and the with statement is used to ensure that the close(),
    method is automatically called when the block of code is finished executing.





##5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg).
    ##,Copy these files from whatever location they are in to a new folder.

Ans-.Here is an example Python program that searches,a folder tree for files with a certain file extension and copies,
    them to a new folder:
        
    import os
    import shutil

    # set the source folder and file extension to search for
    src_folder = '/path/to/source/folder'
    file_ext = '.pdf'

    # set the destination folder to copy the files to
    dest_folder = '/path/to/destination/folder'

    # create the destination folder if it doesn't exist
    if not os.path.exists(dest_folder):
    os.makedirs(dest_folder)

    # walk through the source folder and its subfolders
    for foldername, subfolders, filenames in os.walk(src_folder):
    # loop through the files in the current folder
    for filename in filenames:
    # check if the file has the desired extension
    if filename.endswith(file_ext):
    # get the full path of the file and the destination path
    src_path = os.path.join(foldername, filename)
    dest_path = os.path.join(dest_folder, filename)
    # copy the file to the destination folder
    shutil.copy(src_path, dest_path)
    print(f"Copied {src_path} to {dest_path}")
    
    
    Here's how the program works:

    1.Set the source folder and file extension to search for (src_folder and file_ext).
    2.Set the destination folder to copy the files to (dest_folder).
    3.Check if the destination folder exists, and create it if it doesn't (os.makedirs()).
    4.Use os.walk() to traverse the source folder and its subfolders.
    5.Loop through the files in each folder and check if they have the desired file extension (filename.endswith()).
    6.Get the full path of the file (os.path.join()) and the destination path in the destination folder.
    7.Use shutil.copy() to copy the file to the destination folder.
    8.Print a message indicating the source and destination paths of each file that is copied.
    You can modify the program by changing the src_folder, file_ext, and dest_folder variables to match,
    your specific use case.
