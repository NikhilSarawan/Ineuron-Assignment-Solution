# %%
##1. Make a class called Thing with no contents and print it. Then, create an object called example from this class and also
     #print it.Are the printed values the same or different?

Ans-.class Thing:
    pass

    print(Thing())

    example = Thing()
    print(example)

    The output of this code will be something like:

    <__main__.Thing object at 0x7f9fbf1c1310>
    <__main__.Thing object at 0x7f9fbf1c13d0>
    
    The printed values are different, but they both refer to objects of the same class. Each object has a unique memory address,
    which is why the printed values are different.


##2. Create a new class called Thing2 and add the value 'abc' to the letters class attribute. Letters should be printed.

Ans-.class Thing2:
    letters = 'abc'

    print(Thing2.letters)
    
    The output of this code will be:
        
    abc
    
    In this example, we created a new class called Thing2 and added a class attribute called letters with the value 'abc'. 
    We then printed the value of Thing2.letters, which printed the value of the class attribute 'abc'.








##3. Make yet another class called, of course, Thing3. This time, assign the value 'xyz' to an instance (object),
    #attribute called letters. Print letters. Do you need to make an object from the class to do this?

Ans-.class Thing3:
    def __init__(self):
        self.letters = 'xyz'

    example = Thing3()
    print(example.letters)
    
    The output of this code will be:

    xyz

    In this example, we created a new class called Thing3 and defined an instance attribute called letters inside,
    the __init__ method. We then created an object called example from the class Thing3, and printed the value of ,
    the letters instance attribute for that object using example.letters.

    So, to print the value of letters, we needed to create an object from the Thing3 class first.


##4. Create an Element class with the instance attributes name, symbol, and number. Create a class object with the,
    #values 'Hydrogen,' 'H,' and 1.

Ans-.class Element:
    def __init__(self, name, symbol, number):
        self.name = name
        self.symbol = symbol
        self.number = number

    hydrogen = Element('Hydrogen', 'H', 1)
    print(hydrogen.name)
    print(hydrogen.symbol)
    print(hydrogen.number)
    
    The output of this code will be:

    Hydrogen
    H
    1

    In this example, we created a new class called Element with the instance attributes name, symbol, and number. 
    We then created an object called hydrogen from the Element class, passing in the values 'Hydrogen', 'H',
    and 1 for the name, symbol, and number attributes respectively. Finally, we printed the values of each attribute ,
    for the hydrogen object using hydrogen.name, hydrogen.symbol, and hydrogen.number.





##5. Make a dictionary with these keys and values: 'name': 'Hydrogen', 'symbol': 'H', 'number': 1. Then, 
     #an object called hydrogen from class Element using this dictionary.

Ans-.class Element:
    def __init__(self, name, symbol, number):
        self.name = name
        self.symbol = symbol
        self.number = number

    hydrogen_dict = {'name': 'Hydrogen', 'symbol': 'H', 'number': 1}
    hydrogen = Element(**hydrogen_dict)

    print(hydrogen.name)
    print(hydrogen.symbol)
    print(hydrogen.number)
    
    The output of this code will be:

    In this example, we first created a dictionary called hydrogen_dict with keys 'name', 'symbol', and 'number', 
    and their respective values 'Hydrogen', 'H', and 1. We then created an object called hydrogen from the Element,
    class using the ** syntax to unpack the hydrogen_dict dictionary as arguments for the __init__ method of the Element class.

    Finally, we printed the values of each attribute for the hydrogen object using hydrogen.name, hydrogen.symbol,
    and hydrogen.number. 


##6. For the Element class, define a method called dump() that prints the values of the object’s attributes ,
     #(name, symbol, and number). Create the hydrogen object from this new definition and use dump() to print its attributes.

Ans-.class Element:
    def __init__(self, name, symbol, number):
        self.name = name
        self.symbol = symbol
        self.number = number
    
    def dump(self):
        print(f"Name: {self.name}")
        print(f"Symbol: {self.symbol}")
        print(f"Number: {self.number}")

    hydrogen = Element('Hydrogen', 'H', 1)
    hydrogen.dump()
    
    The output of this code will be:

    Name: Hydrogen
    Symbol: H
    Number: 1

    In this example, we added a new method called dump to the Element class that simply prints out the values of the name, 
    symbol, and number attributes of the object. We then created a new hydrogen object from the Element class, and called,
    the dump method on it using hydrogen.dump(). This printed out the values of the name, symbol, and number attributes for,
    the hydrogen object.






##7. Call print(hydrogen). In the definition of Element, change the name of method dump to __str__, 
    #create a new hydrogen object, and call print(hydrogen) again.

Ans-.class Element:
    def __init__(self, name, symbol, number):
        self.name = name
        self.symbol = symbol
        self.number = number
    
    def __str__(self):
        return f"Name: {self.name}, Symbol: {self.symbol}, Number: {self.number}"

    # creating hydrogen object using the updated Element class with __str__ method
    hydrogen = Element('Hydrogen', 'H', 1)

    # calling print(hydrogen) will now call the __str__ method instead of dump method
    print(hydrogen)
    
    The output of this code will be:
        
    Name: Hydrogen, Symbol: H, Number: 1
                
    In this example, we changed the name of the dump method in the Element class to __str__, which is a special method in Python 
    that is called when an object needs to be converted to a string We updated the __str__ method to return a string that,
    contains, values of the name, symbol, and number attributes.

    We then created a new hydrogen object from the updated Element class, and called print(hydrogen). 
    This calls the __str__ method on the hydrogen object, which returns a string containing the values of the name, symbol,
    and number attributes, and prints it to the console.



##8. Modify Element to make the attributes name, symbol, and number private. Define a getter property for each to return its,
    #value.

Ans-.class Element:
    def __init__(self, name, symbol, number):
        self._name = name
        self._symbol = symbol
        self._number = number
    
    @property
    def name(self):
        return self._name
    
    @property
    def symbol(self):
        return self._symbol
    
    @property
    def number(self):
        return self._number

    # creating hydrogen object using the updated Element class with getter properties
    hydrogen = Element('Hydrogen', 'H', 1)

    # accessing private attributes using getter properties
    print(hydrogen.name)
    print(hydrogen.symbol)
    print(hydrogen.number)

    The output of this code will be:

    Hydrogen
    H
    1
    
    In this example, we modified the Element class by prefixing the name, symbol, and number attributes with an underscore,
    (_), which indicates that they are private attributes.We then defined a getter property for each attribute using ,
    the @property decorator, which allows us to access the private attributes outside of the class using the getter methods.

    We then created a new hydrogen object from the updated Element class, and accessed its private attributes using the getter,
    properties hydrogen.name, hydrogen.symbol, and hydrogen.number. This prints out the values of the name, symbol,
    and number attributes for the hydrogen object.



##9. Define three classes: Bear, Rabbit, and Octothorpe. For each, define only one method: eats().This should return,
    #'berries' (Bear), 'clover' (Rabbit), or 'campers' (Octothorpe). Create one object from each and print what it eats.

Ans-.Here is an example code that defines the Bear, Rabbit, and Octothorpe classes with the eats() method

    class Bear:
    def eats(self):
        return 'berries'
        
    class Rabbit:
    def eats(self):
        return 'carrots'
        
    class Octothorpe:
    def eats(self):
        return 'no idea'
    
    In this example, we defined three classes: Bear, Rabbit, and Octothorpe. For each class, we defined the eats(),
    method that returns a specific string. For the Bear class, the eats() method returns 'berries'. For the Rabbit class,
    the eats() method returns 'carrots'. For the Octothorpe class, the eats() method returns 'no idea'.

    Note that we didn't define any instance attributes or methods other than the eats() method for each class,
    since that was the requirement of the problem.




##10.  Define these classes: Laser, Claw, and SmartPhone. Each has only one method: does(). This returns 'disintegrate' (Laser),'crush' (Claw), or 'ring' (SmartPhone). Then, define the class Robot that has one instance (object) of each of these. Define a does() method for the Robot that prints what its component objects do.

Ans-.Here is an example code that defines the Laser, Claw, SmartPhone, and Robot classes as requested:
    
    
    class Laser:
    def does(self):
        return 'disintegrate'

    class Claw:
    def does(self):
        return 'crush'

    class SmartPhone:
    def does(self):
        return 'ring'

    class Robot:
    def __init__(self):
        self.laser = Laser()
        self.claw = Claw()
        self.smartphone = SmartPhone()
        
    def does(self):
        print(f"Laser: {self.laser.does()}")
        print(f"Claw: {self.claw.does()}")
        print(f"Smartphone: {self.smartphone.does()}")
        
    In this example, we defined the Laser, Claw, and SmartPhone classes with the does() method that returns a specific string.
    For the Laser class, the does() method returns 'disintegrate'. For the Claw class, the does() method returns 'crush'. 
    For the SmartPhone class, the does() method returns 'ring'.

    We then defined the Robot class that has three instance attributes (laser, claw, and smartphone), 
    each containing an object of the Laser, Claw, and SmartPhone classes respectively. We also defined a does() ,
    method for the Robot class that calls the does() method of each of its component objects and prints out what they do.

    We can create a new robot object and call its does() method to see what its component objects do:
