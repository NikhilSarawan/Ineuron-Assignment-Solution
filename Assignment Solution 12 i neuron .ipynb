# %%
##1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?

Ans-.When using the PyPDF2 library in Python, the PdfFileReader() and PdfFileWriter() classes are used to read and write PDF,
    files, respectively.

    For PdfFileReader(), you should open the PDF file object in "rb" (read binary) mode, since a PDF file is a binary file,
    format. Here is an example:
        
    pdf_file = open('example.pdf', 'rb')
    pdf_reader = PyPDF2.PdfFileReader(pdf_file)
    
    For PdfFileWriter(), you should open the PDF file object in "wb" (write binary) mode. Here's an example:
    
    pdf_file = open('output.pdf', 'wb')
    pdf_writer = PyPDF2.PdfFileWriter()
    
    It's important to note that you should always close the file objects using the close() method when you're done with them. 
    Here's an example:
    
    pdf_file.close()




##2. From a PdfFileReader object, how do you get a Page object for page 5?

Ans-.To get a Page object for page 5 from a PdfFileReader object in PyPDF2, you can use the getPage() method and pass the index,
    of the page you want (remember that page indexing starts at 0, not 1). Here is an example code snippet:
    
    import PyPDF2

    # Open the PDF file in read-binary mode
    pdf_file = open('example.pdf', 'rb')

    # Create a PdfFileReader object from the PDF file
    pdf_reader = PyPDF2.PdfFileReader(pdf_file)

    # Get a Page object for page 5 (index 4)
    page_5 = pdf_reader.getPage(4)

    # Close the PDF file
    pdf_file.close()
    
    In this example, the getPage() method is called with an argument of 4, since page indexing starts at 0.
    The page_5 variable will contain a Page object for page 5 of the PDF.

    I hope that helps! Let me know if you have any further questions.


##3. What PdfFileReader variable stores the number of pages in the PDF document?

Ans-.In PyPDF2, the number of pages in a PDF document can be obtained from the numPages attribute of a PdfFileReader object.

    Here's an example code snippet:
    
    import PyPDF2

    # Open the PDF file in read-binary mode
    pdf_file = open('example.pdf', 'rb')

    # Create a PdfFileReader object from the PDF file
    pdf_reader = PyPDF2.PdfFileReader(pdf_file)

    # Get the number of pages in the PDF document
    num_pages = pdf_reader.numPages

    # Close the PDF file
    pdf_file.close()

    # Print the number of pages
    print(f'The PDF document has {num_pages} pages.')
    
    In this example, numPages is an attribute of the pdf_reader object which stores the number of pages in the PDF document. 
    The num_pages variable is assigned this value and can be used elsewhere in your code.

    I hope that helps! Let me know if you have any further questions.
    

##4. If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do before you can obtain,
    # Page objects from it?

Ans-.If a PDF file is encrypted with a password, you must provide the password to PyPDF2 before you can obtain Page,
    objects from it using the PdfFileReader class.

    You can do this by calling the decrypt(password) method on the PdfFileReader object and passing the password as a string.
    Here is an example code snippet
    
    import PyPDF2

    # Open the encrypted PDF file in read-binary mode
    pdf_file = open('example_encrypted.pdf', 'rb')

    # Create a PdfFileReader object from the PDF file
    pdf_reader = PyPDF2.PdfFileReader(pdf_file)

    # Decrypt the PDF file with the password 'swordfish'
    pdf_reader.decrypt('swordfish')

    # Get a Page object for page 5 (index 4)
    page_5 = pdf_reader.getPage(4)

    # Close the PDF file
    pdf_file.close()
    
    In this example, the decrypt() method is called on the pdf_reader object with the password 'swordfish' as an argument.
    This decrypts the PDF file and allows you to obtain Page objects from it using the getPage() method.

    It is important to note that if the PDF file is encrypted with a different password, you must provide the correct,
    password or you will receive a PyPDF2.utils.PdfReadError error.


##5. What methods do you use to rotate a page?

Ans-.To rotate a page in a PDF file using PyPDF2 in Python, you can use the rotateClockwise() or rotateCounterClockwise(),
    method of a PageObject.

    Here is an example code snippet that rotates the first page of a PDF file 90 degrees clockwise and saves the result ,
    to a new PDF file:
        
    import PyPDF2

    # Open the PDF file in read-binary mode
    pdf_file = open('example.pdf', 'rb')

    # Create a PdfFileReader object from the PDF file
    pdf_reader = PyPDF2.PdfFileReader(pdf_file)

    # Get the first page of the PDF file
    page = pdf_reader.getPage(0)

    # Rotate the page 90 degrees clockwise
    page.rotateClockwise(90)

    # Create a PdfFileWriter object
    pdf_writer = PyPDF2.PdfFileWriter()

    # Add the rotated page to the PdfFileWriter object
    pdf_writer.addPage(page)

    # Save the rotated page to a new PDF file
    output_file = open('rotated.pdf', 'wb')
    pdf_writer.write(output_file)
    output_file.close()

    # Close the PDF file
    pdf_file.close()
    
    In this example, the rotateClockwise() method is called on the page object with an argument of 90 degrees to rotate ,
    the page 90 degrees clockwise. You can also use the rotateCounterClockwise() method to rotate the page counterclockwise.

    After rotating the page, the rotated page is added to a new PdfFileWriter object using the addPage() method. Finally, 
    the write() method is called on the PdfFileWriter object to save the rotated page to a new PDF file.

    I hope that helps! Let me know if you have any further questions.


##6. What is the difference between a Run object and a Paragraph object?

Ans-.In Microsoft Word, a Paragraph object represents a single paragraph of text, while a Run object represents a contiguous,
    run of text with the same character formatting.

    Here is an example to illustrate the difference:
    
    This is the first paragraph. It contains a single run of text.

    This is the second paragraph. It contains two runs of text: one in bold, and one in italic.
        
    In this example, the first paragraph contains a single run of text with no formatting applied.
    The second paragraph contains two runs of text with different formatting applied to each run.

    In Microsoft Word, you can access and manipulate the properties of Paragraph and Run objects using the Word Object Model.
    For example, you can change the font size or apply bold formatting to a Run object, or you can set the alignment ,
    indentation of a Paragraph object.

    To summarize, a Paragraph object represents a block of text with a common formatting, while a Run object represents.
    a contiguous run of text with the same formatting within a Paragraph.
    
    


##7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable named doc?

Ans-.To obtain a list of Paragraph objects for a Document object stored in a variable named doc in Python,
    you can use the paragraphs property of the Document object. The paragraphs property returns a list of Paragraph objects,
    in the order they appear in the document.

    Here's an example code snippet that demonstrates how to obtain a list of Paragraph objects for a Document object:
    
    import docx

    # Open the Word document
    doc = docx.Document('example.docx')

    # Get a list of Paragraph objects in the document
    paragraphs = doc.paragraphs

    # Print the text of each Paragraph object
    for paragraph in paragraphs:
    print(paragraph.text)
    
    In this example, the Document object is created by passing the name of the Word document to the docx.Document() constructor.
    The paragraphs property is then used to obtain a list of Paragraph objects, which is stored in the paragraphs variable.

    Finally, a for loop is used to iterate through the Paragraph objects in the list and print the text of each Paragraph,
    object using the text property.

    You can also access individual Paragraph objects by index, like this: paragraph = doc.paragraphs[index], where index is the,
    zero-based index of the Paragraph object you want to access.


##8. What type of object has bold, underline, italic, strike, and outline variables?

Ans-.In Python's docx library, the Font object has bold, underline, italic, strike, and outline variables.

    The Font object represents the character formatting of a run of text within a paragraph in a Microsoft Word document
    The bold, underline, italic, strike, and outline variables are Boolean properties of the Font object that determine,
    whether the run of text is formatted as bold, underlined, italicized, struck-through, or outlined, respectively.

    Here's an example code snippet that demonstrates how to access the Font object of a run of text and modify its ,
    formatting properties:
        
    import docx

    # Open the Word document
    doc = docx.Document('example.docx')

    # Get the first paragraph and the second run of text in it
    paragraph = doc.paragraphs[0]
    run = paragraph.runs[1]

    # Set the bold and italic properties of the Font object for the run of text
    font = run.font
    font.bold = True
    font.italic = True

    # Save the modified document to a new file
    doc.save('modified.docx')
    
    In this example, the Document object is created by passing the name of the Word document to the docx.Document() constructor.
    The paragraphs and runs properties are then used to obtain the first paragraph and the second run of text in it,
    which are stored in the paragraph and run variables, respectively.

    The Font object of the run of text is accessed using the font property, and its bold and italic properties are set to True ,
    to make the run of text bold and italic. Finally, the save() method is called on the Document object to save the modified ,
    document to a new file.


##9. What is the difference between False, True, and None for the bold variable?

Ans-.In Python's docx library, the bold property of the Font object can be set to True, False, or None.

    Setting bold to True makes the text bold.
    Setting bold to False makes the text not bold.
    Setting bold to None preserves the existing boldness of the text.
    When bold is set to None, the Font object inherits the boldness of the style applied to the run of text. 
    If the style has boldness set, the text will be bold; otherwise, it will not be bold.

    Here's an example code snippet that demonstrates how to set the bold property of the Font object to True, False, and None:
    
    import docx

    # Open the Word document
    doc = docx.Document('example.docx')

    # Get the first paragraph and the first run of text in it
    paragraph = doc.paragraphs[0]
    run = paragraph.runs[0]

    # Set the bold property of the Font object for the run of text to True, False, and None
    font = run.font
    font.bold = True
    font.bold = False
    font.bold = None

    # Save the modified document to a new file
    doc.save('modified.docx')
    
    In this example, the Document object is created by passing the name of the Word document to the docx.Document() constructor.
    The paragraphs and runs properties are then used to obtain the first paragraph and the first run of text in it,
    which are stored in the paragraph and run variables, respectively.

    The Font object of the run of text is accessed using the font property, and its bold property is set to True, False, 
    and None to make the text bold, not bold, and preserve its existing boldness, respectively. Finally, the save() method ,
    is called on the Document object to save the modified document to a new file.

    I hope that clarifies the difference between False, True, and None for the bold variable in the Font object.

##10. How do you create a Document object for a new Word document?

Ans-.To create a new Word document in Python using the docx library, you can start by creating a Document object, 
    which represents a new blank Word document. Here's an example code snippet that demonstrates how to create a ,
    new Word document using the docx library
    
    import docx

    # Create a new Document object
    doc = docx.Document()

    # Add some text to the document
    doc.add_paragraph('Hello, world!')
    doc.add_heading('My Heading', level=1)

    # Save the document to a file
    doc.save('my_document.docx')
    
    In this example, the Document object is created by calling the docx.Document() constructor with no arguments,
    which creates a new, empty Word document. You can then add content to the document using the various methods ,
    provided by the Document object, such as add_paragraph() to add a new paragraph of text and add_heading() to add,
    a heading. Finally, you can save the document to a file using the save() method.

    Once you have created the Document object, you can add various types of content to it, such as paragraphs,
    headings, tables, images, and more. You can also format the content using various properties of the Paragraph, Run,
    Table, and other objects provided by the docx library.
    


##11. How do you add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named doc?

Ans-.You can add a new paragraph with the text "Hello, there!" to a Document object stored in a variable named doc using ,
    the add_paragraph() method provided by the docx library.Here's an example code snippet that demonstrates how to do this:
    
    import docx

    # Open an existing Word document
    doc = docx.Document('my_document.docx')

    # Add a new paragraph with the text "Hello, there!"
    doc.add_paragraph('Hello, there!')

    # Save the modified document to a file
    doc.save('my_modified_document.docx')
    
    In this example, the Document object is created by opening an existing Word document named "my_document.docx" ,
    using the docx.Document() constructor. You can then add a new paragraph with the text "Hello, there!" to the ,
    document using the add_paragraph() method provided by the Document object. Finally, you can save the modified ,
    document to a new file using the save() method.

    If you want to add the paragraph at a specific location in the document, you can use the insert_paragraph_before() or,
    insert_paragraph_after() method instead of add_paragraph(). These methods allow you to insert the new paragraph before,
    or after an existing paragraph in the document, respectively.


##12. What integers represent the levels of headings available in Word documents?

Ans-.In Word documents, headings are typically organized into a hierarchy of levels, with level 1 headings being ,
    most important and level 9 headings being the least important. The python-docx library, which is commonly used to ,
    work with Word documents in Python, defines the following integer constants to represent the various heading levels:

    docx.enum.style.WD_STYLE_TYPE.PARAGRAPH: Represents a normal paragraph with no heading level.
    docx.enum.style.WD_STYLE_TYPE.HEADER: Represents a header paragraph, which is not part of the heading hierarchy.
    docx.enum.style.WD_STYLE_TYPE.HEADING_1: Represents a level 1 heading.
    docx.enum.style.WD_STYLE_TYPE.HEADING_2: Represents a level 2 heading.
    docx.enum.style.WD_STYLE_TYPE.HEADING_3: Represents a level 3 heading.
    docx.enum.style.WD_STYLE_TYPE.HEADING_4: Represents a level 4 heading.
    docx.enum.style.WD_STYLE_TYPE.HEADING_5: Represents a level 5 heading.
    docx.enum.style.WD_STYLE_TYPE.HEADING_6: Represents a level 6 heading.
    docx.enum.style.WD_STYLE_TYPE.HEADING_7: Represents a level 7 heading.
    docx.enum.style.WD_STYLE_TYPE.HEADING_8: Represents a level 8 heading.
    docx.enum.style.WD_STYLE_TYPE.HEADING_9: Represents a level 9 heading.
    To use these constants in your code, you can import them from the docx.enum.style module and use them with,
    the add_heading() method provided by the Document object. For example, to add a level 3 heading with the text,
    "My Heading" to a Document object stored in a variable named doc, you can use the following code:
        
    import docx.enum.style as style

    # Add a level 3 heading to the document
    doc.add_heading('My Heading', level=style.WD_STYLE_TYPE.HEADING_3)
