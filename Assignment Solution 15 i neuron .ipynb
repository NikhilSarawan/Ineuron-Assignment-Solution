# %%
##1.How many seconds are in an hour? Use the interactive interpreter as a calculator and multiply the ,
    #number of seconds in a minute (60) by the number of minutes in an hour (also 60).sol. 60 

Ans-.To find the number of seconds in an hour, we can use the interactive interpreter as a calculator,
    and multiply the number of seconds in a minute (60) by the number of minutes in an hour (also 60).

    Entering the calculation "60 * 60" into the interactive interpreter, we get the result:
        
    >>> 60 * 60
    3600
    
    
    Therefore, there are 3600 seconds in an hour.





##2. Assign the result from the previous task (seconds in an hour) to a variable called seconds_per_hour.

Ans-. Here is how to assign the result from the previous task (seconds in an hour) to a variable called seconds_per_hour:
    
    >>> seconds_per_hour = 60 * 60
    >>> seconds_per_hour
    3600
    Now the value of seconds_per_hour is 3600, which is the number of seconds in an hour.




    


##3. How many seconds do you think there are in a day? Make use of the variables seconds per hour and minutes per hour.

Ans-.To find the number of seconds in a day, we need to multiply the number of seconds in an hour ,
    (which we already calculated and stored in the seconds_per_hour variable) by the number of hours in a day. 
    Since there are 24 hours in a day, we can multiply seconds_per_hour by 24 to get the number of seconds in a day.
    
    >>> seconds_per_day = seconds_per_hour * 24
    >>> seconds_per_day
    86400

    Therefore, there are 86,400 seconds in a day.




##4.Calculate seconds per day again, but this time save the result in a variable called seconds_per_day

Ans-.Here is how to calculate the number of seconds in a day and save the result in a variable called seconds_per_day:
    
  
    >>> seconds_per_day = seconds_per_hour * 24
    >>> seconds_per_day
    86400

    Now the value of seconds_per_day is 86,400, which is the number of seconds in a day.
    


##5. Divide seconds_per_day by seconds_per_hour. Use floating-point (/) division.

Ans-.Here is how to divide seconds_per_day by seconds_per_hour using floating-point division:
    >>> seconds_per_day / seconds_per_hour
    24.0
    
    The result is 24.0, which means that there are 24 hours in a day (which we already knew!).





##6. Divide seconds_per_day by seconds_per_hour, using integer (//) division. Did this number ,
    #agree with the floating-point value from the previous question, aside from the final .0?

Ans-.Here is how to divide seconds_per_day by seconds_per_hour using integer division:
    
    >>> seconds_per_day // seconds_per_hour
    24
    The result is 24, which is the same as the floating-point result we got earlier, but without the decimal point. 
    So yes, the integer division result agrees with the floating-point division result aside from the final .0.

##7. Write a generator, genPrimes, that returns the sequence of prime numbers on successive calls to its next(),
     #method: 2, 3, 5, 7, 11, ...

Ans-.def genPrimes():
    # Initialize the list of prime numbers with the first two primes
    primes = [2, 3]
    # Start the generator loop at the index of the last prime found
    i = 1
    while True:
        # Generate the next candidate prime number
        candidate = primes[i] + 2
        # Check if it is prime by testing it against all previous primes
        while any(candidate % p == 0 for p in primes):
            candidate += 2
        # If it is prime, add it to the list of primes and yield it
        primes.append(candidate)
        yield candidate
        # Move to the next index for the next loop iteration
        i += 1
